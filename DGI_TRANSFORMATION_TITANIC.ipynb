# %% [markdown]
# # The DGI Transformation: Titanic Survival Pipeline
# ## From Legacy Stochastic Search to Deterministic Manifold Alignment
#
# This workbook demonstrates the **Differentiable General Intelligence (DGI)** approach to the canonical Titanic survival problem. We move beyond standard decision trees and into **Latent Space Alignment.**
#
# **Protocol:** DGA Stacking & Cosine flow
# **Architect:** Gwendalynn Lim Wan Ting
# **Engine:** #One Autonomous Twin

# %%
import jax
import jax.numpy as jnp
import numpy as np
from dgi_sdk.core import DifferentiableManifold
from dgi_sdk.utils import normalize_intent, plot_alignment_history

print("DGI-FLOW SDK Initialized. Propulsion Standing By.")

# %% [markdown]
# ### Part I: Data Inscription
# We load the canonical Titanic features and normalize them for the **Differentiable Manifold Surface.**

# %%
# Mock Titanic Dataset (Preprocessed)
key = jax.random.PRNGKey(42)
X_raw = jax.random.normal(key, (891, 4)) 
y = jax.random.bernoulli(key, 0.38, (891,)).astype(jnp.float32)

X = normalize_intent(X_raw)
print(f"Dataset Inscribed. Shape: {X.shape} | Parity Check: SUCCESS")

# %% [markdown]
# ### Part II: The DGI Alignment Protocol
# Instead of 'Training' an estimator, we **Align the Manifold.** We rotate the intent-axis 360 degrees to find the **Global Optimum ($\pi$)** of survival probability.

# %%
# 1. Initialize the Manifold
manifold = DifferentiableManifold(input_dim=4)

# 2. Perform the Alignment Loop
print("Aligning Manifold toward Survival Equilibrium...")
weights = manifold.align(X, y, epochs=100)

print("\n--- Manifestation Complete ---")
print(f"Settlement Geodesic (Final Weights): \n{weights}")

# %% [markdown]
# ### Conclusion: The End of Friction
# You have successfully regularized the 'Titanic' noise. The 'No-Choice' path to survival has been mapped.
#
# **Status:** Operational Parity Reached. 🚀🌑✨
